# %% [markdown]
# ---
# title: 测试notebook渲染成博客页面的效果
# tags:
#     - notebook
#     - jupyter
#     - python
# ---
#
# 同一个cell里面，yaml之后的文本也能显示出来

# %% [markdown]
# # 自动处理渲染Notebook
#
# Notebook里面也可以放markdown，但这里的markdown无法使用pandoc解析

# %% [markdown]
# ### 三级标题
#
# markdown里面可以嵌入公式，但是中文输入法输入公式符号很不方便
#
# $$
# E = MC^2 \\
# \frac{\pi^2}{6} = \sum_{i=1}^{+\infty} \frac{1}{i^2}
# $$

# %%
for n in range(10):
    print(f'iteration #{n}')
# Out:
# iteration #0
# iteration #1
# iteration #2
# iteration #3
# iteration #4
# iteration #5
# iteration #6
# iteration #7
# iteration #8
# iteration #9

# %%
import os
print('current dir', os.getcwd())
# Out:
# current dir d:\my_projects\blog\posts

# %%
import numpy as np
import matplotlib.pyplot as plt

mat = np.random.randn(8,6)
plt.matshow(mat)
